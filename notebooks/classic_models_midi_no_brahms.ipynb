# %% [markdown]
# # Classic models (MIDI) — vodič kroz notebook
#
# Isti zadatak kao u `classic_models_raw.ipynb` — prepoznavanje kompozitora po djelu — ali atributi se ovdje
# izvlače iz MusicNet-ovih note-level (MIDI) anotacija (`train_labels/`, `test_labels/`), ne iz audio signala.
# Nikakav `.wav` se ne učita, pa je ovaj pipeline mnogo brži od audio verzije.
#
# Isti metodološki okvir: `work_id` grupisanje, `StratifiedGroupKFold`, work-level majority vote, macro F1
# kao glavna metrika (dataset je neuravnotežen po kompozitorima).

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, "..")

# %% [markdown]
# # Ucitavanje podataka

# %% [markdown]
# ## Priprema metapodataka
#
# Pregled izvorne tabele i raspodjele kompozitora nalazi se u [metadata.ipynb](metadata.ipynb).
# `load_metadata()` iz `dataset.py` učitava CSV, formira `work_id` kao `composer + " | " + composition`
# i zadržava kompozitore sa najmanje `MIN_WORKS_PER_COMPOSER` različitih djela (podrazumijevano 5, iz `config.py`).
# Svi stavovi istog djela tako ostaju u istoj grupi tokom evaluacije.
#
# Ova sveska se izvršava samostalno; nije potrebno prethodno pokretati `metadata.ipynb`.

# %%
import numpy as np
import pandas as pd

from src.features.dataset import load_metadata
from src.utils.paths import AUDIO_DIR

metadata_filtered = load_metadata(exclude_composers="Brahms")

# %%
print(
    metadata_filtered.groupby("composer")["work_id"]
    .nunique()
    .sort_values()
)
# Out:
# composer
# Schubert      9
# Mozart       11
# Bach         30
# Beethoven    55
# Name: work_id, dtype: int64

# %% [markdown]
# ---
#
# ## Group-aware evaluacija
#
# Želimo da mjerimo generalizaciju na **nova djela**, ne na nove segmente poznatog djela. `StratifiedGroupKFold`
# drži sve segmente istog `work_id` u istom foldu i približno čuva raspodjelu kompozitora po foldovima.

# %%
from sklearn import metrics
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from src.model.evaluation import make_sample_weights, majority_vote_prediction
from src.model.classical_model import run_classical_train_pipeline

sgkf = StratifiedGroupKFold(
    n_splits=4,
    shuffle=True,
    random_state=42
)

sgkf_outer = StratifiedGroupKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %% [markdown]
# ---
#
# # MIDI model
#
# Svaka nota u MusicNet anotacijama ima visinu, instrument, tačan onset/offset i trajanje u otkucajima.
# `extract_midi_features` (u `midi.py`) iz toga računa gustinu nota, melodijski kontur (interval mean/std,
# udio uzlaznih/silaznih/ponovljenih koraka), histogram tonskih klasa, histogram instrumenata (11 fiksnih GM
# programa u MusicNet-u), on-beat/off-beat omjer i raspon akorada.
#
# Napomena: `end_beat` kolona u MusicNet CSV-u je zapravo **trajanje note u otkucajima**, ne apsolutna
# pozicija (provjereno — `end_beat < start_beat` za svaki red u fajlu).

# %%
from src.features.midi import make_midi_dataset

X_midi, y_midi, groups_midi = make_midi_dataset(metadata_filtered, AUDIO_DIR)
# Out:
# Processing MIDI labels:  19%|█▉        | 54/278 [00:08<00:25,  8.90it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  33%|███▎      | 93/278 [00:10<00:06, 26.75it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  35%|███▍      | 96/278 [00:10<00:08, 20.82it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:
/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  89%|████████▉ | 247/278 [00:49<00:10,  3.05it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  89%|████████▉ | 248/278 [00:49<00:08,  3.52it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  90%|████████▉ | 249/278 [00:49<00:07,  3.93it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  90%|████████▉ | 250/278 [00:49<00:07,  3.78it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  90%|█████████ | 251/278 [00:50<00:07,  3.47it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  91%|█████████ | 252/278 [00:50<00:10,  2.58it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  91%|█████████ | 253/278 [00:51<00:09,  2.72it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  91%|█████████▏| 254/278 [00:51<00:07,  3.05it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  92%|█████████▏| 255/278 [00:51<00:06,  3.64it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  92%|█████████▏| 256/278 [00:51<00:06,  3.55it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  92%|█████████▏| 257/278 [00:51<00:05,  3.99it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  93%|█████████▎| 258/278 [00:52<00:04,  4.55it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  93%|█████████▎| 259/278 [00:52<00:04,  4.17it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  94%|█████████▎| 260/278 [00:52<00:04,  4.16it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  94%|█████████▍| 261/278 [00:53<00:04,  3.50it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  94%|█████████▍| 262/278 [00:53<00:05,  3.17it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  95%|█████████▍| 263/278 [00:53<00:04,  3.27it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  95%|█████████▍| 264/278 [00:53<00:04,  3.29it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  95%|█████████▌| 265/278 [00:54<00:03,  3.51it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  96%|█████████▌| 266/278 [00:54<00:02,  4.17it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  96%|█████████▌| 267/278 [00:54<00:02,  4.94it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  96%|█████████▋| 268/278 [00:54<00:02,  3.79it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  97%|█████████▋| 269/278 [00:55<00:02,  3.38it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  97%|█████████▋| 270/278 [00:55<00:02,  2.67it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  97%|█████████▋| 271/278 [00:55<00:02,  3.22it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  98%|█████████▊| 273/278 [00:56<00:01,  3.88it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  99%|█████████▊| 274/278 [00:56<00:00,  4.29it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels:  99%|█████████▉| 275/278 [00:56<00:00,  4.81it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels: 100%|█████████▉| 277/278 [00:56<00:00,  5.26it/s]c:\Users\marko.vucic_ominimo\Desktop\music-classifier\.venv\Lib\site-packages\pretty_midi\pretty_midi.py:122: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Processing MIDI labels: 100%|██████████| 278/278 [00:57<00:00,  4.86it/s]

# %%
rfc_model = RandomForestClassifier(
    max_features="sqrt",
    random_state=42,
    n_jobs=-1
)

param_grid = {
    "n_estimators": [500], # tried [50, 100, 300] but models statistically improve with more estimators with ceiling at ~500
    "max_depth": [20], # tried 30 as well - but 20 is ceiling here
    "min_samples_leaf": [1, 3, 5] # regularization
}

_ = run_classical_train_pipeline(
    X=X_midi,
    y=y_midi, 
    groups=groups_midi, 
    model=rfc_model, 
    cv=sgkf, 
    param_grid=param_grid, 
    outer_cv=sgkf_outer
)
# Out:
# n_estimators=500, max_depth=20, min_samples_leaf=1: accuracy=0.8355, macro_f1=0.7067
# n_estimators=500, max_depth=20, min_samples_leaf=3: accuracy=0.8469, macro_f1=0.7199
# n_estimators=500, max_depth=20, min_samples_leaf=5: accuracy=0.8355, macro_f1=0.7124
#
# Best params: {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 3}
# Best accuracy: 0.8468614718614719
# Best macro F1: 0.7198729259870564
#
# outer fold: best_params={'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 3} -> accuracy=0.9500, macro_f1=0.9391
#
# n_estimators=500, max_depth=20, min_samples_leaf=1: accuracy=0.8349, macro_f1=0.7555
# n_estimators=500, max_depth=20, min_samples_leaf=3: accuracy=0.8104, macro_f1=0.7338
# n_estimators=500, max_depth=20, min_samples_leaf=5: accuracy=0.8343, macro_f1=0.7496
#
# Best params: {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 1}
# Best accuracy: 0.8349025974025974
# Best macro F1: 0.7555489257119692
#
# outer fold: best_params={'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 1} -> accuracy=0.8571, macro_f1=0.8613
#
# n_estimators=500, max_depth=20, min_samples_leaf=1: accuracy=0.8933, macro_f1=0.8092
# n_estimators=500, max_depth=20, min_samples_leaf=3: accuracy=0.8701, macro_f1=0.7882
# n_estimators=500, max_depth=20, min_samples_leaf=5: accuracy=0.8944, macro_f1=0.8494
#
# Best params: {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 5}
# Best accuracy: 0.894426406926407
# Best macro F1: 0.8494335827216262
#
# outer fold: best_params={'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 5} -> accuracy=0.7619, macro_f1=0.5750
#
# n_estimators=500, max_depth=20, min_samples_leaf=1: accuracy=0.8212, macro_f1=0.7039
# n_estimators=500, max_depth=20, min_samples_leaf=3: accuracy=0.8326, macro_f1=0.7182
# n_estimators=500, max_depth=20, min_samples_leaf=5: accuracy=0.8326, macro_f1=0.7122
#
# Best params: {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 3}
# Best accuracy: 0.8325757575757576
# Best macro F1: 0.7182334332334332
#
# outer fold: best_params={'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 3} -> accuracy=0.8571, macro_f1=0.6341
#
# n_estimators=500, max_depth=20, min_samples_leaf=1: accuracy=0.8083, macro_f1=0.6940
# n_estimators=500, max_depth=20, min_samples_leaf=3: accuracy=0.8202, macro_f1=0.7304
# n_estimators=500, max_depth=20, min_samples_leaf=5: accuracy=0.8202, macro_f1=0.7304
#
# Best params: {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 3}
# Best accuracy: 0.8202380952380952
# Best macro F1: 0.7304065499717672
#
# outer fold: best_params={'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 3} -> accuracy=0.9091, macro_f1=0.8414
#
#               precision    recall  f1-score   support
#
#         Bach       1.00      0.87      0.93        30
#    Beethoven       0.84      0.95      0.89        55
#       Mozart       0.70      0.64      0.67        11
#     Schubert       0.86      0.67      0.75         9
#
#     accuracy                           0.87       105
#    macro avg       0.85      0.78      0.81       105
# weighted avg       0.87      0.87      0.87       105
#
# Overall work accuracy: 0.8666666666666667
# Overall work macro F1: 0.808531746031746

# %% [markdown]
# ## ------ SVM Model --------------------------------------

# %%
from sklearn import preprocessing
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

param_grid = {
    "C": [10 ** i for i in range(-1, 3)],
    "gamma": [0.001, 0.005, 0.01, 0.1]
}

svm_model = make_pipeline(
    StandardScaler(),
    SVC(
        kernel = 'rbf',
        class_weight = None
    )
)

_ = run_classical_train_pipeline(
    X=X_midi,
    y=y_midi, 
    groups=groups_midi, 
    model=svm_model, 
    cv=sgkf, 
    param_grid=param_grid, 
    outer_cv=sgkf_outer
)
# Out:
# svc__C=0.1, svc__gamma=0.001: accuracy=0.6721, macro_f1=0.5204
# svc__C=0.1, svc__gamma=0.005: accuracy=0.7311, macro_f1=0.6810
# svc__C=0.1, svc__gamma=0.01: accuracy=0.7430, macro_f1=0.6642
# svc__C=0.1, svc__gamma=0.1: accuracy=0.5915, macro_f1=0.3793
# svc__C=1, svc__gamma=0.001: accuracy=0.7657, macro_f1=0.7012
# svc__C=1, svc__gamma=0.005: accuracy=0.7900, macro_f1=0.7069
# svc__C=1, svc__gamma=0.01: accuracy=0.8122, macro_f1=0.6942
# svc__C=1, svc__gamma=0.1: accuracy=0.6591, macro_f1=0.3351
# svc__C=10, svc__gamma=0.001: accuracy=0.8128, macro_f1=0.7281
# svc__C=10, svc__gamma=0.005: accuracy=0.8122, macro_f1=0.7057
# svc__C=10, svc__gamma=0.01: accuracy=0.7890, macro_f1=0.6380
# svc__C=10, svc__gamma=0.1: accuracy=0.6591, macro_f1=0.3351
# svc__C=100, svc__gamma=0.001: accuracy=0.8355, macro_f1=0.7223
# svc__C=100, svc__gamma=0.005: accuracy=0.7771, macro_f1=0.6338
# svc__C=100, svc__gamma=0.01: accuracy=0.7419, macro_f1=0.5385
# svc__C=100, svc__gamma=0.1: accuracy=0.6591, macro_f1=0.3351
#
# Best params: {'svc__C': 100, 'svc__gamma': 0.001}
# Best accuracy: 0.8354978354978355
# Best macro F1: 0.7222591719874328
#
# outer fold: best_params={'svc__C': 100, 'svc__gamma': 0.001} -> accuracy=0.9000, macro_f1=0.8939
#
# svc__C=0.1, svc__gamma=0.001: accuracy=0.6918, macro_f1=0.5989
# svc__C=0.1, svc__gamma=0.005: accuracy=0.7872, macro_f1=0.7338
# svc__C=0.1, svc__gamma=0.01: accuracy=0.7753, macro_f1=0.7335
# svc__C=0.1, svc__gamma=0.1: accuracy=0.6334, macro_f1=0.4330
# svc__C=1, svc__gamma=0.001: accuracy=0.8110, macro_f1=0.7588
# svc__C=1, svc__gamma=0.005: accuracy=0.8116, macro_f1=0.7330
# svc__C=1, svc__gamma=0.01: accuracy=0.7985, macro_f1=0.7279
# svc__C=1, svc__gamma=0.1: accuracy=0.6436, macro_f1=0.3351
# svc__C=10, svc__gamma=0.001: accuracy=0.8348, macro_f1=0.7575
# svc__C=10, svc__gamma=0.005: accuracy=0.8695, macro_f1=0.7848
# svc__C=10, svc__gamma=0.01: accuracy=0.8344, macro_f1=0.7434
# svc__C=10, svc__gamma=0.1: accuracy=0.6436, macro_f1=0.3351
# svc__C=100, svc__gamma=0.001: accuracy=0.8332, macro_f1=0.7516
# svc__C=100, svc__gamma=0.005: accuracy=0.8225, macro_f1=0.6994
# svc__C=100, svc__gamma=0.01: accuracy=0.7629, macro_f1=0.6070
# svc__C=100, svc__gamma=0.1: accuracy=0.6436, macro_f1=0.3351
#
# Best params: {'svc__C': 10, 'svc__gamma': 0.005}
# Best accuracy: 0.869534632034632
# Best macro F1: 0.7847826086956521
#
# outer fold: best_params={'svc__C': 10, 'svc__gamma': 0.005} -> accuracy=0.7619, macro_f1=0.7532
#
# svc__C=0.1, svc__gamma=0.001: accuracy=0.6930, macro_f1=0.6463
# svc__C=0.1, svc__gamma=0.005: accuracy=0.7997, macro_f1=0.7760
# svc__C=0.1, svc__gamma=0.01: accuracy=0.8008, macro_f1=0.7645
# svc__C=0.1, svc__gamma=0.1: accuracy=0.6561, macro_f1=0.3683
# svc__C=1, svc__gamma=0.001: accuracy=0.7883, macro_f1=0.7545
# svc__C=1, svc__gamma=0.005: accuracy=0.8014, macro_f1=0.7619
# svc__C=1, svc__gamma=0.01: accuracy=0.8354, macro_f1=0.7916
# svc__C=1, svc__gamma=0.1: accuracy=0.6799, macro_f1=0.3704
# svc__C=10, svc__gamma=0.001: accuracy=0.7775, macro_f1=0.7416
# svc__C=10, svc__gamma=0.005: accuracy=0.8701, macro_f1=0.8013
# svc__C=10, svc__gamma=0.01: accuracy=0.8808, macro_f1=0.7943
# svc__C=10, svc__gamma=0.1: accuracy=0.6442, macro_f1=0.3403
# svc__C=100, svc__gamma=0.001: accuracy=0.8587, macro_f1=0.7921
# svc__C=100, svc__gamma=0.005: accuracy=0.8581, macro_f1=0.7654
# svc__C=100, svc__gamma=0.01: accuracy=0.8348, macro_f1=0.6857
# svc__C=100, svc__gamma=0.1: accuracy=0.6442, macro_f1=0.3403
#
# Best params: {'svc__C': 10, 'svc__gamma': 0.01}
# Best accuracy: 0.8808441558441559
# Best macro F1: 0.7942586580086579
#
# outer fold: best_params={'svc__C': 10, 'svc__gamma': 0.01} -> accuracy=0.7143, macro_f1=0.5408
#
# svc__C=0.1, svc__gamma=0.001: accuracy=0.6681, macro_f1=0.6256
# svc__C=0.1, svc__gamma=0.005: accuracy=0.7163, macro_f1=0.6861
# svc__C=0.1, svc__gamma=0.01: accuracy=0.7640, macro_f1=0.7225
# svc__C=0.1, svc__gamma=0.1: accuracy=0.6436, macro_f1=0.3409
# svc__C=1, svc__gamma=0.001: accuracy=0.7276, macro_f1=0.6756
# svc__C=1, svc__gamma=0.005: accuracy=0.7384, macro_f1=0.6605
# svc__C=1, svc__gamma=0.01: accuracy=0.8093, macro_f1=0.7009
# svc__C=1, svc__gamma=0.1: accuracy=0.6317, macro_f1=0.3260
# svc__C=10, svc__gamma=0.001: accuracy=0.7741, macro_f1=0.7026
# svc__C=10, svc__gamma=0.005: accuracy=0.8320, macro_f1=0.7226
# svc__C=10, svc__gamma=0.01: accuracy=0.8088, macro_f1=0.7105
# svc__C=10, svc__gamma=0.1: accuracy=0.6203, macro_f1=0.3141
# svc__C=100, svc__gamma=0.001: accuracy=0.8206, macro_f1=0.7113
# svc__C=100, svc__gamma=0.005: accuracy=0.7974, macro_f1=0.6944
# svc__C=100, svc__gamma=0.01: accuracy=0.8088, macro_f1=0.6882
# svc__C=100, svc__gamma=0.1: accuracy=0.6203, macro_f1=0.3141
#
# Best params: {'svc__C': 10, 'svc__gamma': 0.005}
# Best accuracy: 0.8319805194805195
# Best macro F1: 0.7225901996554172
#
# outer fold: best_params={'svc__C': 10, 'svc__gamma': 0.005} -> accuracy=0.9048, macro_f1=0.7798
#
# svc__C=0.1, svc__gamma=0.001: accuracy=0.7000, macro_f1=0.5990
# svc__C=0.1, svc__gamma=0.005: accuracy=0.7708, macro_f1=0.7112
# svc__C=0.1, svc__gamma=0.01: accuracy=0.7833, macro_f1=0.7359
# svc__C=0.1, svc__gamma=0.1: accuracy=0.5518, macro_f1=0.3375
# svc__C=1, svc__gamma=0.001: accuracy=0.7839, macro_f1=0.7299
# svc__C=1, svc__gamma=0.005: accuracy=0.8077, macro_f1=0.7495
# svc__C=1, svc__gamma=0.01: accuracy=0.8202, macro_f1=0.7676
# svc__C=1, svc__gamma=0.1: accuracy=0.6506, macro_f1=0.3292
# svc__C=10, svc__gamma=0.001: accuracy=0.8077, macro_f1=0.7495
# svc__C=10, svc__gamma=0.005: accuracy=0.8083, macro_f1=0.7589
# svc__C=10, svc__gamma=0.01: accuracy=0.7958, macro_f1=0.6993
# svc__C=10, svc__gamma=0.1: accuracy=0.6506, macro_f1=0.3292
# svc__C=100, svc__gamma=0.001: accuracy=0.8083, macro_f1=0.7559
# svc__C=100, svc__gamma=0.005: accuracy=0.7714, macro_f1=0.6466
# svc__C=100, svc__gamma=0.01: accuracy=0.7470, macro_f1=0.5546
# svc__C=100, svc__gamma=0.1: accuracy=0.6506, macro_f1=0.3292
#
# Best params: {'svc__C': 1, 'svc__gamma': 0.01}
# Best accuracy: 0.8202380952380953
# Best macro F1: 0.7676089309241483
#
# outer fold: best_params={'svc__C': 1, 'svc__gamma': 0.01} -> accuracy=0.8636, macro_f1=0.8007
#
#               precision    recall  f1-score   support
#
#         Bach       1.00      0.87      0.93        30
#    Beethoven       0.83      0.89      0.86        55
#       Mozart       0.43      0.55      0.48        11
#     Schubert       1.00      0.67      0.80         9
#
#     accuracy                           0.83       105
#    macro avg       0.81      0.74      0.77       105
# weighted avg       0.85      0.83      0.83       105
#
# Overall work accuracy: 0.8285714285714286
# Overall work macro F1: 0.7670551378446115

# %% [markdown]
# ---
#
# ## XGBoost
#
# Gradient boosting ansambl — stabla se dodaju sekvencijalno, svako ispravlja greške prethodnih. Često
# nadmaši Random Forest na ovakvim tabelarnim feature setovima. `LabelEncoder` je potreban jer XGBoost
# očekuje numeričke labele, ne stringove.

# %%
from xgboost import XGBClassifier
from sklearn import preprocessing
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

xgb_model = XGBClassifier(
    n_estimators=400,
    max_depth=5,
    learning_rate=0.1,
    eval_metric="mlogloss",
    random_state=42,
    n_jobs=-1
)

_ = run_classical_train_pipeline(
    X=X_midi,
    y=y_midi, 
    groups=groups_midi, 
    model=xgb_model, 
    cv=sgkf, 
    label_encode=True
    # param_grid=param_grid, 
    # outer_cv=sgkf_outer
)
# Out:
# : accuracy=0.8576, macro_f1=0.7288
#
# Best params: {}
# Best accuracy: 0.857579365079365
# Best macro F1: 0.7287936390793732
#
#               precision    recall  f1-score   support
#
#         Bach       1.00      0.87      0.93        30
#    Beethoven       0.85      0.96      0.91        55
#       Mozart       0.67      0.55      0.60        11
#     Schubert       0.62      0.56      0.59         9
#
#     accuracy                           0.86       105
#    macro avg       0.79      0.73      0.76       105
# weighted avg       0.86      0.86      0.85       105
#
# Overall work accuracy: 0.8571428571428571
# Overall work macro F1: 0.7556974071679955
